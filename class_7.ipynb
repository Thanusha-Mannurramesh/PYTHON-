# %% [markdown]
# <a href="https://colab.research.google.com/github/Thanusha-Mannurramesh/PYTHON-/blob/main/class_7.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ![Pandas-Basic-Operations-1.webp](data:image/webp;base64,...)![Pandas-Basic-Operations-2.webp](data:image/webp;base64,...)![Pandas-Basic-Operations-5.webp](data:image/webp;base64,...)![Pandas-Basic-Operations-3.webp](data:image/webp;base64,...)![Pandas-Basic-Operations-4.webp](data:image/webp;base64,...)
